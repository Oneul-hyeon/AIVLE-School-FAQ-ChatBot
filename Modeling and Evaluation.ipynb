# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 불러오기

# %%
import joblib
import pandas as pd
import numpy as np
import gensim
import tensorflow as tf
import warnings 
warnings.filterwarnings('ignore')

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from keras.backend import clear_session
from keras.layers import Input, Dense, Embedding, LSTM
from keras.models import Model
from keras.optimizers import Adam

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### (2) 데이터 로딩

# %%
dataset = joblib.load('/Users/hyeontae/Desktop/AIVLE-School-FAQ-ChatBot/dataset.pkl')

# %% [markdown]
# ## 2.Modeling

# %% [markdown]
# ### (1) train/test dataset 분리
#    * test dataset : intent마다 무작위로 질문 2개를 뽑아 test 데이터로 분리
#    * train dataset : 나머지 데이터

# %%
# test dataset
test_dataset = dataset.loc[dataset['intent'] == 1].sample(n=2, random_state = 42)

for i in range(2, dataset['intent'].max()+1) :
    test_dataset = pd.concat([test_dataset, dataset.loc[dataset['intent'] == i].sample(n=2, random_state = 42)])

# train dataset
train_dataset = dataset.drop(test_dataset.index)

# 인덱스 초기화
train_dataset = train_dataset.reset_index(drop = True)
test_dataset = test_dataset.reset_index(drop = True)

# %% [markdown]
# ### (2) STEP 1 : Type 분류 모델링(LSTM)

# %% [markdown]
# #### 1) 데이터 준비

# %% [markdown]
# - label

# %%
y_train = train_dataset['type']
y_test = test_dataset['type']

# %% [markdown]
# - 토큰화

# %%
# 각각의 토큰에 인덱스를 부여하는 토크나이저 생성
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_dataset['Q'])

# 전체 토큰의 수로 vocab_size 지정
vocab_size = len(tokenizer.index_word) + 1

# 토크나이즈 된 데이터를 가지고 모두 시퀀스로 변환
x_train = tokenizer.texts_to_sequences(train_dataset['Q'])
x_test = tokenizer.texts_to_sequences(test_dataset['Q'])

# %% [markdown]
# - Padding

# %%
max_sequence_length = max(train_dataset['Q'].apply(lambda x : len(x)))

x_train= pad_sequences(x_train, maxlen = max_sequence_length)
x_test = pad_sequences(x_test, maxlen= max_sequence_length)

# %% [markdown]
# #### 2) Modeling

# %%
# 1. 이전 세션 클리어
clear_session
# 2. 모델 엮기
il = Input(shape = (x_train.shape[1],))

el = Embedding(input_dim = vocab_size,
               output_dim = 256,
               input_length = max_sequence_length)(il)
lstm_l = LSTM(128, return_sequences= False)(el)
ol = Dense(1, activation = 'sigmoid')(lstm_l)

# 3. 모델 선언
model = Model(il, ol)
# 4. 모델 컴파일
model.compile(loss = 'binary_crossentropy', metrics = ['accuracy'], optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.01))
# 5. 모델 요약
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 144)]             0
#
#  embedding_3 (Embedding)     (None, 144, 256)          343040
#
#  lstm_3 (LSTM)               (None, 128)               197120
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 540289 (2.06 MB)
# Trainable params: 540289 (2.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor = 'val_loss',
                   min_delta = 0,
                   patience = 5,
                   verbose = 1,
                   restore_best_weights = True)

# %%
model.fit(x_train, y_train, epochs = 1000, callbacks = [es], validation_split = 0.2, verbose = 1)
# Out:
# Epoch 1/1000
# 30/30 [==============================] - 4s 103ms/step - loss: 0.1952 - accuracy: 0.9024 - val_loss: 0.1482 - val_accuracy: 0.9623
# Epoch 2/1000
# 30/30 [==============================] - 3s 103ms/step - loss: 7.2214e-05 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9623
# Epoch 3/1000
# 30/30 [==============================] - 3s 99ms/step - loss: 2.9502e-05 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9623
# Epoch 4/1000
# 30/30 [==============================] - 3s 114ms/step - loss: 2.1399e-05 - accuracy: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9623
# Epoch 5/1000
# 30/30 [==============================] - 3s 107ms/step - loss: 1.7408e-05 - accuracy: 1.0000 - val_loss: 0.2339 - val_accuracy: 0.9623
# Epoch 6/1000
# 30/30 [==============================] - ETA: 0s - loss: 1.4580e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 1.
# 30/30 [==============================] - 3s 101ms/step - loss: 1.4580e-05 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.9582
# Epoch 6: early stopping

# %% [markdown]
# #### 3) Evaluation

# %%
y_pred = model.predict(x_test)
y_pred_binary = np.where(y_pred > 0.5, 1, 0)

print(classification_report(y_test, y_pred_binary))
# Out:
# 4/4 [==============================] - 0s 22ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       1.00      1.00      1.00        46
#
#     accuracy                           1.00       106
#    macro avg       1.00      1.00      1.00       106
# weighted avg       1.00      1.00      1.00       106

# %% [markdown]
# ### (3) STEP 2 : Word Embedding(Word2Vec)
#
# * Pre-trained Word2Vec model
#     * ko.bin
# * 사전학습 모델을 로딩하고, train 데이터셋의 질문(Q)을 임베딩벡터로 만들어, 열(Column)로 추가

# %% [markdown]
# #### 1) Model Loading

# %%
pre_wv_model = gensim.models.Word2Vec.load('/Users/hyeontae/Desktop/AIVLE-School-FAQ-ChatBot/ko/ko.bin')

# %%
# 모델의 벡터크기 조회
size = pre_wv_model.vector_size

# %% [markdown]
# #### 2) train_data에 임베딩벡터 결과 저장

# %% [markdown]
# - 함수 정의

# %%
# Word2Vec 모델로부터 하나의 문장을 벡터화 시키는 함수
def get_sent_embedding(model, embedding_size, tokenized_words):
    # 임베딩 벡터를 0으로 초기화
    feature_vec = np.zeros((embedding_size,), dtype='float32')
    # 단어 개수 초기화
    n_words = 0
    # 모델 단어 집합 생성
    index2word_set = set(model.wv.index2word)
    # 문장의 단어들을 하나씩 반복
    for word in tokenized_words:
        # 모델 단어 집합에 해당하는 단어일 경우에만
        if word in index2word_set:
            # 단어 개수 1 증가
            n_words += 1
            # 임베딩 벡터에 해당 단어의 벡터를 더함
            feature_vec = np.add(feature_vec, model[word])
    # 단어 개수가 0보다 큰 경우 벡터를 단어 개수로 나눠줌 (평균 임베딩 벡터 계산)
    if (n_words > 0):
        feature_vec = np.divide(feature_vec, n_words)
    return feature_vec

# %% [markdown]
# - train_data의 질문별 임베딩 결과 저장

# %%
train_dataset['Q_embedding'] = train_dataset.Q.apply(lambda x : get_sent_embedding(pre_wv_model, size, x))

# %% [markdown]
# ### (3) ChatBot 구축

# %% [markdown]
# #### 1) 함수 생성

# %%
def ChatBot(question):
    input = [list(question.split(' '))]
    input = tokenizer.texts_to_sequences(input)
    input = pad_sequences(input, maxlen= max_sequence_length)

    y_pred = model.predict(input)
    y_pred = np.where(y_pred > 0.5, 1, 0)
    data = train_dataset.loc[train_dataset['type'] == y_pred[0][0]]
    data = data.reset_index(drop= True)

    vector = get_sent_embedding(pre_wv_model, 200, question)
    data_vector = list(data['Q_embedding'])
    pred_classes = np.argmax(cosine_similarity([vector], data_vector))

    answers = data['A'].loc[data['intent'] == data['intent'][pred_classes]]
    print(f'질문 : {question}')
    print(f'대답 : {np.random.choice(answers)}')
    return

# %% [markdown]
# #### 2) Test

# %%
for text in test_dataset['Q'] :
    ChatBot(text)
    print('----------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# 1/1 [==============================] - 0s 12ms/step
# 질문 : 떨어뜨려서 핸드폰 액정 나갔어
# 대답 : as 맡기세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# 질문 : 액정 나갔어
# 대답 : 술 안 마셔도 놀 수 있어요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 내 의지 는 상관없나 봐
# 대답 : 제가 있잖아요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 질문 : 내 의지 로 안되는 일인 가 봐
# 대답 : 맛있게 드세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# 질문 : 코 가 막혀서 싫어
# 대답 : 감기 조심하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 질문 : 오늘 날씨 가 생각 보다 차갑네
# 대답 : 감기 조심하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# 질문 : 산책 가볼까
# 대답 : 많이 만나보세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# 질문 : 일요일 에 교회 만 가
# 대답 : 같이 가자고 말해보세요
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 피곤 한테 또 잠 은 안 와
# 대답 : 고민이 있나 봐요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# 질문 : 항상 선택 할 때 힘들어
# 대답 : 많이 만나보세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# 질문 : 공부 시작 해도 될까
# 대답 : 공부 좋죠.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 영어학원 좀 다닐까
# 대답 : 공부가 최우선이죠.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# 질문 : 친한 친구 라고 생각 했는데
# 대답 : 그런 친구는 거르세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# 질문 : 친구 라고 생각 했는데 날 엄청 쉽게 생각 했나 봐
# 대답 : 그런 친구 말고 제대로 된 친구 사귀세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 질문 : 나 좀 건 들 지 말 라고 해
# 대답 : 너무 무리하지 마세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# 질문 : 중병
# 대답 : 직장 스트레스 심하겠네요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# 질문 : 감기 걸렸나 봐
# 대답 : 꾸준히 치료하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# 질문 : 공황장애 있어
# 대답 : 꾸준히 치료하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# 질문 : 진짜 내 집 이 생겼어
# 대답 : 내 집 마련 축하드려요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# 질문 : 새 집 가기 로 했어
# 대답 : 내 집 마련 축하드려요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# 질문 : 아침 메뉴 뭐 먹을까
# 대답 : 냉장고 파먹기 해보세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# 질문 : 뭐 먹을 거 없나
# 대답 : 냉장고 파먹기 해보세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 94ms/step
# 질문 : 말 잘 해
# 대답 : 노력하겠습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 말 을 이해 를 못 해
# 대답 : 노력하고 있어요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# 질문 : 힘든 것 좀 끝났으면
# 대답 : 성공을 기원합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 66ms/step
# 질문 : 프로젝트 끝났으면 좋겠다
# 대답 : 다 잘 될 거예요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# 질문 : 출근 하고 올게
# 대답 : 다녀오세요. 기다릴게요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# 질문 : 에버랜드 가고 싶어
# 대답 : 다녀오세요!
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 택시 비 가 너무 많이 나와
# 대답 : 직장 스트레스 심하겠네요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 질문 : 출퇴근 시간 이 좀 줄어들었으면 좋겠다
# 대답 : 너무 무리하면 지쳐요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# 질문 : 돈 많이 벌고 싶어
# 대답 : 저도요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# 질문 : 내 실력 좀 쩌 는 듯
# 대답 : 동감입니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# 질문 : 자장가 불러 달랬더니 불러 줬어
# 대답 : 로맨틱하네요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# 질문 : 덕수궁 돌담 길 따라서 둘 이 걸었어
# 대답 : 로맨틱하네요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# 질문 : 미세먼지 심해
# 대답 : 마스크 쓰고 나가세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# 질문 : 미세먼지 가 너무 많아서 짜증 나
# 대답 : 너무 무리하면 지쳐요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 소개팅 할까
# 대답 : 많이 만나보세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# 질문 : 부모님 이 선 보 래
# 대답 : 좋은 생각이에요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 질문 : 스테끼 먹은 거 몇 년 만이 냐
# 대답 : 맛있는거 드세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# 질문 : 참외 맛있다
# 대답 : 저도요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# 질문 : 앞차 랑 박았어
# 대답 : 조심하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 질문 : 무서워서 뛰어왔어
# 대답 : 보험처리 하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 17ms/step
# 질문 : 속 더부룩해
# 대답 : 너무 신경 곤두세우지 마세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# 질문 : 과식 해서 소화 가 안 돼
# 대답 : 소화제 챙겨드세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# 질문 : 술 끊을 거야
# 대답 : 술이 웬수예요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 14ms/step
# 질문 : 술 먹으면 항상 실수 해
# 대답 : 술 너무 많이 드시지 마세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# 질문 : 일이 너무 많아
# 대답 : 직장 스트레스가 심한가봐요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# 질문 : 빡빡 한 일상
# 대답 : 조심하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 아빠 보고 싶다
# 대답 : 연락이라도 드려보세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 엄마 아빠 보고 싶다
# 대답 : 연락드려보세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 주말 에 만나자고 해볼까
# 대답 : 용기를 내세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# 질문 : 짝사랑 한테 빼빼로 줘도 될까
# 대답 : 용기를 내요!
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 오늘 따라 엄마 보고 싶어
# 대답 : 감기 조심하세요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 해외여행 가고 싶다
# 대답 : 저도요!
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 뭐 하지
# 대답 : 제가 있잖아요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 공부 하기 싫어
# 대답 : 너무 무리하면 지쳐요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# 질문 : 친구 들 부르려고
# 대답 : 좋은 생각이에요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# 질문 : 친구 들 초대 하려고
# 대답 : 좋은 생각이에요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 편입 성공했어
# 대답 : 내 집 마련 축하드려요.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# 질문 : 꽃게탕 맛있다
# 대답 : 저도요!!
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# 질문 : 미성년 자 가 지원 하면 어떻게 되나요
# 대답 : KT 에이블스쿨은 정규 4년제 대학 졸업자 및 졸업예정자 중 만 34세 이하 미취업자를 대상으로 하는 교육입니다.
# 단, 모집시점에 만 35세여도 해당연도 1월 1일 이후 생일자는 지원이 가능합니다.
# 또한 전공의 종류와는 무관 합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# 질문 : 지원 자격 기준 에서 나이 제한 이 있는지 알려주세요
# 대답 : KT 에이블스쿨은 정규 4년제 대학 졸업자 및 졸업예정자 중 만 34세 이하 미취업자를 대상으로 하는 교육입니다.
# 단, 모집시점에 만 35세여도 해당연도 1월 1일 이후 생일자는 지원이 가능합니다.
# 또한 전공의 종류와는 무관 합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# 질문 : 프리랜서 인 경우 지원 할 수 없나요
# 대답 : KT 에이블스쿨은 미취업자를 대상으로 하며, 교육 시작일 기준 재직자는 지원이 불가능합니다.
# 미취업자의 기준은 아래와 같습니다.
# 1) 기간의 정함이 있는 근로인 경우
# 2) 고용보험에 미가입한 경우
# 3) 고용보험에 가입되어 있더라도 15시간/주 미만 근로인 경우
# 단, 어떠한 경우에도 교육을 풀타임(09:00~18:00)으로 들을 수 있어야 교육 참여가 가능합니다.
#
# 프리랜서 계약의 경우, 고용보험에 가입하지 않은 경우 미취업자로 보지만, 개인별 상황이 다를 수 있어서 관할 고용센터에 문의하여 확인하시기 바랍니다.
# 또한 현재 군 복무 중인 상태여도 지원 가능하며, 교육 시작 전일까지 병역 의무를 마쳐야 교육 수강이 가능합니다.
#
# 퇴사 후 고용보험 상실이 완료되어 실업급여를 수급 중인 경우, 훈련 수강에는 문제가 없습니다.
# 다만, 실업급여와 훈련장려금은 중복 수급이 불가하여 실업급여 지급이 종료된 후 훈련장려금 지급이 개시됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 군 복무 중인 경우 교육 지원이 어려운 점 이 있는데 어떻게 대처 해야 할까 요 지원 은 가능한가요
# 대답 : KT 에이블스쿨은 미취업자를 대상으로 하며, 교육 시작일 기준 재직자는 지원이 불가능합니다.
# 미취업자의 기준은 아래와 같습니다.
# 1) 기간의 정함이 있는 근로인 경우
# 2) 고용보험에 미가입한 경우
# 3) 고용보험에 가입되어 있더라도 15시간/주 미만 근로인 경우
# 단, 어떠한 경우에도 교육을 풀타임(09:00~18:00)으로 들을 수 있어야 교육 참여가 가능합니다.
#
# 프리랜서 계약의 경우, 고용보험에 가입하지 않은 경우 미취업자로 보지만, 개인별 상황이 다를 수 있어서 관할 고용센터에 문의하여 확인하시기 바랍니다.
# 또한 현재 군 복무 중인 상태여도 지원 가능하며, 교육 시작 전일까지 병역 의무를 마쳐야 교육 수강이 가능합니다.
#
# 퇴사 후 고용보험 상실이 완료되어 실업급여를 수급 중인 경우, 훈련 수강에는 문제가 없습니다.
# 다만, 실업급여와 훈련장려금은 중복 수급이 불가하여 실업급여 지급이 종료된 후 훈련장려금 지급이 개시됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# 질문 : 이전 에 불합격 했을 경우 이번 에 다시 지원 할 수 있나요
# 대답 : 지원자격에 해당되는 경우 다시 지원이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 코딩 테스트 탈락자 도 재지 원할 수 있나요
# 대답 : 코딩테스트는 AI개발자 Track 지원자를 대상으로 진행되며, 사용 가능한 프로그래밍 언어는 C, C++, JAVA, Python, JavaScript 5가지입니다.
# 자세한 내용은 서류전형 합격자 대상으로 안내드릴 예정입니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# 질문 : 합격 후 과정 을 포기 하면 재 지원이 불가능한가요
# 대답 : 교육 등록신청을 하지 않거나 교육 일정 시작 전에 교육 등록을 취소해도 지원자격에 해당하는 경우 다시 지원이 가능합니다.
# 다만, 교육 과정 확정자신고일(교육시작일로부터 7일)이 지난 후 중도 퇴교를 할 경우 과정을 수강한 것으로 간주되며, 향후 K-Digital Training (K-DT) 과정에 재지원은 가능하나 무료 수강은 어렵습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 교육 과정 을 중도 포기 할 경우 이력서 에 해당 과정 수료 여부 를 어떻게 표기 해야 할까 요
# 대답 : 교육 등록신청을 하지 않거나 교육 일정 시작 전에 교육 등록을 취소해도 지원자격에 해당하는 경우 다시 지원이 가능합니다.
# 다만, 교육 과정 확정자신고일(교육시작일로부터 7일)이 지난 후 중도 퇴교를 할 경우 과정을 수강한 것으로 간주되며, 향후 K-Digital Training (K-DT) 과정에 재지원은 가능하나 무료 수강은 어렵습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# 질문 : 추가 합격 제도 가 있나요
# 대답 : 단위기간(훈련시작일로부터 1개월) 내 80% 이상 출석해야 훈련수강 유지가 가능합니다.
# 예를 들어, 훈련시작일로부터 1개월을 기준으로 1개월간의 훈련일수가 20일이라고 가정할 경우 16일 이상 출석하셔야 훈련수강을 계속 유지할 수 있습니다.
# 결석 기준은 1. 당일 소정훈련시간의 50퍼센트 미만을 수강한 경우, 2. 지각, 조퇴 3회 누적 시, 결석 처리 됩니다.
# 훈련 수준 유지를 위해 100% 출석을 권고 드립니다.
#
# K-Digital Training (K-DT) 규정상 월 1회 휴가 사용이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 추가 합격 제도 는 어떤 형태 로 운영 되나요
# 대답 : 현재 KT 에이블스쿨은 추가합격 제도를 운영하고 있지 않습니다.
# 향후 추가합격을 운영하는 경우, 사전에 공지할 예정입니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# 질문 : 면접 은 어떻게 진행 되나요
# 대답 : KT 에이블스쿨은 별도의 면접 과정이 없습니다
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 비대 면 면접 이 있나요
# 대답 : KT 에이블스쿨은 별도의 면접 과정이 없습니다
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 12ms/step
# 질문 : 코딩 테스트 는 어떻게 진행 되나요
# 대답 : 코딩테스트는 AI개발자 Track 지원자를 대상으로 진행되며, 사용 가능한 프로그래밍 언어는 C, C++, JAVA, Python, JavaScript 5가지입니다.
# 자세한 내용은 서류전형 합격자 대상으로 안내드릴 예정입니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 개발자 에 지원 한 경우 코딩 테스트 를 쳐야 하나요
# 대답 : 코딩테스트는 AI개발자 Track 지원자를 대상으로 진행되며, 사용 가능한 프로그래밍 언어는 C, C++, JAVA, Python, JavaScript 5가지입니다.
# 자세한 내용은 서류전형 합격자 대상으로 안내드릴 예정입니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# 질문 : 인 적성검사 는 채용 과 같은 과목 인가요
# 대답 : 현재 KT 에이블스쿨은 KT 채용 인적성검사와 같은 과목의 인적성검사를 운영하고 있습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 인 적성검사 과목 은 인 적성검사 과목 과 같나요
# 대답 : 현재 KT 에이블스쿨은 KT 채용 인적성검사와 같은 과목의 인적성검사를 운영하고 있습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# 질문 : 휴학 중 이어서 졸업 증명서 발급 이 안되는 경우 어떻게 해야 하나요
# 대답 : 학교 사정으로 졸업예정증명서 발급이 불가능한 경우 수료증명서 또는 재학증명서를 제출하여 주시기 바라며, 추후 졸업예정증명서 발급 가능 시점에 제출 요청을 드릴 수 있습니다.
# 대학원 재학 중으로 성적증명서가 없으신 경우, 최종학력은 대학교로 입력하여 주시고 졸업(예정)증명서 및 성적증명서 제출란에는 재학증명서를 제출하여 주시기 바랍니다.
# 국외 대학의 경우, 졸업을 확인할 수 있는 서류인 공식 졸업장(예: Diploma)과, 4년간의 이수 과목과 성적을 확인할 수 있는 성적표(예: Transcript)를 제출하시면 됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 휴학 중인 경우 어떤 서류 를 제출 해야 하나요
# 대답 : 학교 사정으로 졸업예정증명서 발급이 불가능한 경우 수료증명서 또는 재학증명서를 제출하여 주시기 바라며, 추후 졸업예정증명서 발급 가능 시점에 제출 요청을 드릴 수 있습니다.
# 대학원 재학 중으로 성적증명서가 없으신 경우, 최종학력은 대학교로 입력하여 주시고 졸업(예정)증명서 및 성적증명서 제출란에는 재학증명서를 제출하여 주시기 바랍니다.
# 국외 대학의 경우, 졸업을 확인할 수 있는 서류인 공식 졸업장(예: Diploma)과, 4년간의 이수 과목과 성적을 확인할 수 있는 성적표(예: Transcript)를 제출하시면 됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 전 공지 식 이 없는데 커리큘럼 을 따라갈 수 있나요
# 대답 : 비전공자도 SW개발에 관심과 열정이 있으신 분들은 충분히 따라 갈 수 있습니다. 이 경우 데이터 사이언스 기반으로 산업 현장에 AI를 접목하고 DX를 이끄는 DX컨설턴트 Track을 추천 드립니다. SW기초 지식 및 코딩역량을 보유하고 있고 개발자로 성장하고 싶은 분께는 AI개발자 Track을 추천 드립니다. 파이썬 프로그래밍 사용법과 AI 개념에 대한 기초 이해를 공부하고 오시면 도움이 되실 것 같습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# 질문 : 전 공 기초 가 없는데 수업 을 따라갈 수 있나요
# 대답 : 비전공자도 SW개발에 관심과 열정이 있으신 분들은 충분히 따라 갈 수 있습니다.
# 이 경우 데이터 사이언스 기반으로 산업 현장에 AI를 접목하고 DX를 이끄는 DX컨설턴트 Track을 추천 드립니다.
# SW기초 지식 및 코딩역량을 보유하고 있고 개발자로 성장하고 싶은 분께는 AI개발자 Track을 추천 드립니다.
#
# 파이썬 프로그래밍 사용법과 AI 개념에 대한 기초 이해를 공부하고 오시면 도움이 되실 것 같습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# 질문 : 일부 결석 이 가능한 경우 가 있나요
# 대답 : KT 에이블스쿨은 전국 어디서나 참여할 수 있도록, 온/오프라인을 병행하여 탄력적으로 운영합니다.
# 오프라인 교육장소는 6개 권역(수도권, 강원권, 부산/경남권, 대구/경북권, 충남/충북권, 전남/전북권)에 위치하고 있습니다.
#
# 서류 접수 마감 이후에 지원 지역(교육 장소) 변경은 불가능하며, 최종 합격된 지역에서만 교육이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# 질문 : 출석 이 저조한 경우 어떻게 되나요
# 대답 : 단위기간(훈련시작일로부터 1개월) 내 80% 이상 출석해야 훈련수강 유지가 가능합니다.
# 예를 들어, 훈련시작일로부터 1개월을 기준으로 1개월간의 훈련일수가 20일이라고 가정할 경우 16일 이상 출석하셔야 훈련수강을 계속 유지할 수 있습니다.
# 결석 기준은 1. 당일 소정훈련시간의 50퍼센트 미만을 수강한 경우, 2. 지각, 조퇴 3회 누적 시, 결석 처리 됩니다.
# 훈련 수준 유지를 위해 100% 출석을 권고 드립니다.
#
# K-Digital Training (K-DT) 규정상 월 1회 휴가 사용이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 교육 수료 기준 은 무엇 인가요
# 대답 : KT 에이블스쿨은 고용노동부 K-Digital Training 사업으로 운영됨에 따라 총 훈련일수의 80% 이상을 출석한 경우 수료대상이 됩니다.
# 반대로, 총 훈련일수의 20%를 초과하여 결석한 경우 제적대상이 됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 온라인 교육 에서 출석 체크 방법 은 어떻게 되나요
# 대답 : KT 에이블스쿨은 전국 어디서나 참여할 수 있도록, 온/오프라인을 병행하여 탄력적으로 운영합니다.
# 오프라인 교육장소는 6개 권역(수도권, 강원권, 부산/경남권, 대구/경북권, 충남/충북권, 전남/전북권)에 위치하고 있습니다.
#
# 서류 접수 마감 이후에 지원 지역(교육 장소) 변경은 불가능하며, 최종 합격된 지역에서만 교육이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 15ms/step
# 질문 : 오프라인 교육 장소 위치 가 궁금합니다
# 대답 : KT 에이블스쿨은 전국 어디서나 참여할 수 있도록, 온/오프라인을 병행하여 탄력적으로 운영합니다.
# 오프라인 교육장소는 6개 권역(수도권, 강원권, 부산/경남권, 대구/경북권, 충남/충북권, 전남/전북권)에 위치하고 있습니다.
#
# 서류 접수 마감 이후에 지원 지역(교육 장소) 변경은 불가능하며, 최종 합격된 지역에서만 교육이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 13ms/step
# 질문 : 지방 에도 교육 장소 가 있나요
# 대답 : KT 에이블스쿨은 전국 어디서나 참여할 수 있도록, 온/오프라인을 병행하여 탄력적으로 운영합니다.
# 오프라인 교육장소는 6개 권역(수도권, 강원권, 부산/경남권, 대구/경북권, 충남/충북권, 전남/전북권)에 위치하고 있습니다.
#
# 서류 접수 마감 이후에 지원 지역(교육 장소) 변경은 불가능하며, 최종 합격된 지역에서만 교육이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# 질문 : 대면 교육 도 진행 하나요
# 대답 : 교육 과정 중 STEP1과 STEP2는 대부분 비대면 교육으로 진행하며, 일부 프로젝트는 대면으로 진행될 수 있습니다. STEP3 프로젝트 수행기간에는 대면 & 비대면을 병행하여 진행합니다. (단, 코로나 정부방역지침에 따라 변경될 수 있습니다.)
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# 질문 : 교육 과정 중 언제 비 대면 으로 진행 되나요
# 대답 : 교육 과정 중 STEP1과 STEP2는 대부분 비대면 교육으로 진행하며, 일부 프로젝트는 대면으로 진행될 수 있습니다. STEP3 프로젝트 수행기간에는 대면 & 비대면을 병행하여 진행합니다. (단, 코로나 정부방역지침에 따라 변경될 수 있습니다.)
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# 질문 : 비대 면 교육 은 자유롭게 수강 가능한가요
# 대답 : KT 에이블스쿨은 풀타임(09:00~18:00)으로 교육이 진행되며, 정해진 시간에 필수로 참여해야 합니다.
# 교육에 풀타임으로 참여할 수 있어야 교육 수강이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# 질문 : 비대 면 교육 은 원하는 시간대 에 참여 해도 되나요
# 대답 : KT 에이블스쿨은 풀타임(09:00~18:00)으로 교육이 진행되며, 정해진 시간에 필수로 참여해야 합니다.
# 교육에 풀타임으로 참여할 수 있어야 교육 수강이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 핸드폰 으로도 수강 할 수 있나요
# 대답 : 교육기간 동안 노트북을 무료로 지원하며, 교육에 필요한 필수 프로그램이 설치되어 있으므로, 제공한 노트북을 사용해 주시기 바랍니다.
#
# 원활한 실습 환경을 위해 아래 명시된 사양 이상을 갖춘 노트북을 제공합니다.
# - CPU : I5 / RAM : 8GB / 여유저장공간 : 40GB
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 패드 로 도 수강 할 수 있나요
# 대답 : KT 에이블스쿨은 미취업자를 대상으로 하며, 교육 시작일 기준 재직자는 지원이 불가능합니다.
# 미취업자의 기준은 아래와 같습니다.
# 1) 기간의 정함이 있는 근로인 경우
# 2) 고용보험에 미가입한 경우
# 3) 고용보험에 가입되어 있더라도 15시간/주 미만 근로인 경우
# 단, 어떠한 경우에도 교육을 풀타임(09:00~18:00)으로 들을 수 있어야 교육 참여가 가능합니다.
#
# 프리랜서 계약의 경우, 고용보험에 가입하지 않은 경우 미취업자로 보지만, 개인별 상황이 다를 수 있어서 관할 고용센터에 문의하여 확인하시기 바랍니다.
# 또한 현재 군 복무 중인 상태여도 지원 가능하며, 교육 시작 전일까지 병역 의무를 마쳐야 교육 수강이 가능합니다.
#
# 퇴사 후 고용보험 상실이 완료되어 실업급여를 수급 중인 경우, 훈련 수강에는 문제가 없습니다.
# 다만, 실업급여와 훈련장려금은 중복 수급이 불가하여 실업급여 지급이 종료된 후 훈련장려금 지급이 개시됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# 질문 : 교육과정 중 시험 이 있나요
# 대답 : KT 에이블스쿨은 자기주도적인 학습을 장려하고 있으며, 교과목 종료 시 셀프테스트를 통한 역량 점검이 진행 됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 교육 기간 동안 의 테스트 및 시험 은 개별 적 으로 진행 되나요 아니면 특정 날짜 에 일괄 적 으로 진행 되나요
# 대답 : KT 에이블스쿨은 풀타임(09:00~18:00)으로 교육이 진행되며, 정해진 시간에 필수로 참여해야 합니다.
# 교육에 풀타임으로 참여할 수 있어야 교육 수강이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# 질문 : 교육 수강 중 졸업 이 유예 된 경우 어떻게 되나요
# 대답 : KT 에이블스쿨은 풀타임(09:00~18:00)으로 교육이 진행되며, 정해진 시간에 필수로 참여해야 합니다.
# 교육에 풀타임으로 참여할 수 있어야 교육 수강이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 졸업 이 미뤄졌는데 졸업 후 에 채용 연 계 를 받을 수 있나요
# 대답 : 교육수강은 가능합니다. 다만 교육수료와 함께 이루어지는 채용 연계 시 참가한 기업에서 졸업자가 아니므로 채용하지 않을 수 있습니다.
# 해당 시점 채용공고에서 각 기업 별 내용을 직접 확인해야합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# 질문 : 에이 블 스쿨 은 무료 인가요
# 대답 : KT 에이블스쿨에서는 이론/실습 교육에 나아가 기업 실전형 프로젝트를 중심으로 실무에서 일하는 방식을 배울 수 있습니다. 또한, KT 현직 전문가가 전담하여 산업지식, AI/DX 기술, 창의성을 갖출 수 있도록 강의와 코칭을 제공하고, 강의 중 궁금한 사항은 전담 튜터가 1:10로 직접 코칭을 제공합니다. 특히, 우수 수료생을 대상으로 KT와 KT 그룹, AI원팀, 협력사 등 채용까지 연계해 드립니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# 질문 : 결제 해야 하는 금액 이 얼마 인가요
# 대답 : 학교 사정으로 졸업예정증명서 발급이 불가능한 경우 수료증명서 또는 재학증명서를 제출하여 주시기 바라며, 추후 졸업예정증명서 발급 가능 시점에 제출 요청을 드릴 수 있습니다.
# 대학원 재학 중으로 성적증명서가 없으신 경우, 최종학력은 대학교로 입력하여 주시고 졸업(예정)증명서 및 성적증명서 제출란에는 재학증명서를 제출하여 주시기 바랍니다.
# 국외 대학의 경우, 졸업을 확인할 수 있는 서류인 공식 졸업장(예: Diploma)과, 4년간의 이수 과목과 성적을 확인할 수 있는 성적표(예: Transcript)를 제출하시면 됩니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# 질문 : 채용 연 계 관련 어떤 지원이 있나요
# 대답 : KT 에이블스쿨은 미래인재육성 + 청년 IT/SW/DX 분야 일자리 창출을 위해서 KT 와 정부가 함께 하는 프로그램입니다. 에이블러 여러분들의 취업기회를 위해 Job Searching 세션, 취업컨설팅, 잡페어 등 여러 프로그램들을 운영하고 있습니다.
# KT 직접채용은 그 일환 중 하나이며, KT에 합격한 1기 수료생의 경우 해당지역에 배치되었습니다. KT 외에 KT 그룹사, 주요 협력사, AI원팀 기업, 스타트업 등의 채용은 지역 구분 없이 진행됩니다. 채용 상황에 따라 변경될 수 있어 교육 수료 후 채용 연계 시 상세 안내 드리겠습니다. KT 그룹, AI 원팀 기업/스타트업 100 등 다양한 기업에서 채용 연계할 예정으로 기업마다 인재상 및 반영 요소가 다르기 때문에 중점 요소에 대해 안내드리기 어려운 점 양해 부탁드립니다. 채용에 대한 부분은 교육을 참여하시면 추후 관련 부서를 통해 안내드릴 예정입니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# 질문 : 취업컨설팅 이 있나요
# 대답 : KT 에이블스쿨은 미래인재육성 + 청년 IT/SW/DX 분야 일자리 창출을 위해서 KT 와 정부가 함께 하는 프로그램입니다. 에이블러 여러분들의 취업기회를 위해 Job Searching 세션, 취업컨설팅, 잡페어 등 여러 프로그램들을 운영하고 있습니다.
# KT 직접채용은 그 일환 중 하나이며, KT에 합격한 1기 수료생의 경우 해당지역에 배치되었습니다. KT 외에 KT 그룹사, 주요 협력사, AI원팀 기업, 스타트업 등의 채용은 지역 구분 없이 진행됩니다. 채용 상황에 따라 변경될 수 있어 교육 수료 후 채용 연계 시 상세 안내 드리겠습니다. KT 그룹, AI 원팀 기업/스타트업 100 등 다양한 기업에서 채용 연계할 예정으로 기업마다 인재상 및 반영 요소가 다르기 때문에 중점 요소에 대해 안내드리기 어려운 점 양해 부탁드립니다. 채용에 대한 부분은 교육을 참여하시면 추후 관련 부서를 통해 안내드릴 예정입니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 질문 : 교육 생 지원 혜택 으로 제공 되는 장학금 이나 지원 금은 어떤 조건 에서 받을 수 있는가요
# 대답 : 취업에 도움이 되는 다양한 프로젝트를 제공하고, 포트폴리오 작성을 도와드리며, 코딩챌린지, 해커톤 등 다양한 Competition 수상 기회를 제공합니다.
# 또한, AIVLE Job Fair를 거쳐 우수 수료생을 대상으로 KT와 KT그룹, AI원팀, 협력사 등 채용까지 연계해 드립니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# 질문 : 교육 생 지원 혜택 을 받으려면 어떤 절차 를 거쳐야 하나요
# 대답 : KT 에이블스쿨은 전국 어디서나 참여할 수 있도록, 온/오프라인을 병행하여 탄력적으로 운영합니다.
# 오프라인 교육장소는 6개 권역(수도권, 강원권, 부산/경남권, 대구/경북권, 충남/충북권, 전남/전북권)에 위치하고 있습니다.
#
# 서류 접수 마감 이후에 지원 지역(교육 장소) 변경은 불가능하며, 최종 합격된 지역에서만 교육이 가능합니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 56ms/step
# 질문 : 대면 교육 시 숙소 가 제공 되나요
# 대답 : 숙소 및 기숙사에 대한 지원은 제공하지 않습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# 질문 : 숙소 나 기숙사 이용 료 는 어떻게 결제 하나요 할인 혜택 이 있는가요
# 대답 : 숙소 및 기숙사에 대한 지원은 제공하지 않습니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# 질문 : 국비 지원 교육 이 많은데 똑같은 거 아닌가요 뭐 가 다른 가요
# 대답 : KT 에이블스쿨에서는 이론/실습 교육에 나아가 기업 실전형 프로젝트를 중심으로 실무에서 일하는 방식을 배울 수 있습니다. 또한, KT 현직 전문가가 전담하여 산업지식, AI/DX 기술, 창의성을 갖출 수 있도록 강의와 코칭을 제공하고, 강의 중 궁금한 사항은 전담 튜터가 1:7로 직접 코칭을 제공합니다. 특히, 우수 수료생을 대상으로 KT와 KT 그룹, AI원팀, 협력사 등 채용까지 연계해 드립니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 74ms/step
# 질문 : 다른 교육 과 차이점 이 있나요
# 대답 : KT 에이블스쿨에서는 이론/실습 교육에 나아가 기업 실전형 프로젝트를 중심으로 실무에서 일하는 방식을 배울 수 있습니다. 또한, KT 현직 전문가가 전담하여 산업지식, AI/DX 기술, 창의성을 갖출 수 있도록 강의와 코칭을 제공하고, 강의 중 궁금한 사항은 전담 튜터가 1:4로 직접 코칭을 제공합니다. 특히, 우수 수료생을 대상으로 KT와 KT 그룹, AI원팀, 협력사 등 채용까지 연계해 드립니다.
# ----------------------------------------------------------------------------------------------------------------------------------------
